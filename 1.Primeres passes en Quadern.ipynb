# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img = mpimg.imread('/content/logoUPC.png')
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# # 1.1 Autor

# %%
img = mpimg.imread('/content/PerePonsa.png')
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# Primeres passes en la confecció d'un quadern. **Pere Ponsa** Sistemes d'Informació i Comunicació Industrial (SICI)

# %% [markdown]
# # 1.2 Importar llibreries

# %% [markdown]
# En primer lloc cal IMPORTAR les llibreries de Python al quadern.
# Voleu informació sobre Pandas? Aquest tutorial de InteractiveChaos us pot ser útil.
# [link text](https://interactivechaos.com/es/manual/tutorial-de-pandas/tutorial-de-pandas)

# %% [markdown]
# Utilitzem + Code per afegir codi en Python.
# Utilitzem + Text per afegir comentaris al quadern.
# En aquest espai estem inportant la llibreria Pandas al quadern.

# %%
import pandas as pd

# %% [markdown]
# # 1.3 Importar dades

# %% [markdown]
# Si tenim un conjunt de dades en format online cal portar-les al quadern utilitzant 'url'

# %%
url = 'https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv'

# %% [markdown]
# les dades es llegueixen del fitxer amb extensió .csv que es troba en la URL amb la instrucció:

# %%
data=pd.read_csv(url)

# %% [markdown]
# Amb .head() tenim les dades ordenades per columnes

# %%
data.head()
# Out:
#     Country  Region
# 0   Algeria  AFRICA
# 1    Angola  AFRICA
# 2     Benin  AFRICA
# 3  Botswana  AFRICA
# 4   Burkina  AFRICA

# %% [markdown]
# Si no tenim les dades disponibles on line, cal anar a un repositori de
# DADES OBERTES (Diputació, Ciutat, Generalitat) i descarregar el fitxer
# amb extensió CSV al nostre ordinador.
# Exemple, qualitat de l'aigua de les fonts naturals de la ciutat de Barcelona en aquest enllaç: [link text](https://dadesobertes.diba.cat/datasets/qualitat-de-laigua-de-les-fonts-naturals)
# Per carregar les dades del fitxer CSV al quadern cal fer servir les
# dues següents instruccions.
# Farem servir un fitxer amb dades sobre Visitants a Montserrat.

# %%
from google.colab import files

# %%
upload = files.upload()
# Out:
#      <input type="file" id="files-582ffb09-8363-48eb-a974-e8506a85c115" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-582ffb09-8363-48eb-a974-e8506a85c115">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Es carrega el fitxer del nostre ordinador a l'espai de memòria del quadern

# %% [markdown]
# Per exemple, si s'ha descarregat el fitxer "Visitants_a_Montserrat.csv" del portal de Transparència (exportar), enllaç [link text](https://analisi.transparenciacatalunya.cat/Transport/Visitants-a-Montserrat/mgtw-h7tg/data)
# i l'afegim al quadern creat, trobarem aquest fitxer dins del path //content/
# ![visitants.png](data:image/png;base64,...)

# %%
import pandas as pd
data=pd.read_csv('//content/Visitants_a_Montserrat.csv')

# %% [markdown]
# I si declarem les dades en forma de data, Pandas ens permet poder veure les dades que s'observaven en DADES en OBERT, dins el nostre quadern estructurat en forma de files i columnes.

# %%
data.head()
# Out:
#     ANY     MES   BUS  MOTO  COTXE  TOTAL VISITANTS APARCAMENT    FGC   AERI  \
# 0  2011   Gener   486   204  12801                       65226  21597   7364
# 1  2011  Febrer   516   221  11557                       62344  25823   6344
# 2  2011    Març  1100   306  13871                       96002  35534  12123
# 3  2011   Abril  1889   414  20354                      152876  51919  18262
# 4  2011    Maig  2572   429  18522                      176658  54529  17859
#
#    TOTAL VISITANTS  APARCAMENT_100  FGC_100  AERI_100
# 0            94187          0.6925   0.2293    0.0782
# 1            94511          0.6596   0.2732    0.0671
# 2           143659          0.6683   0.2473    0.0844
# 3           223057          0.6854   0.2328    0.0819
# 4           249046          0.7093   0.2190    0.0717

# %% [markdown]
# Ara cal que analitzem si es necessaris filtrar les dades, seleccionar columnes, fer un tractament de dades abans de passar a la visualització

# %% [markdown]
# # 1.4 Exercici Google Drive

# %% [markdown]
# Dins del quadern, a la part de files (menú esquerra de la pantalla), podem ncorporar els fitxers CSV que necessitem.
# **Exercici: buscar informació per tal de vincular Google Colab amb els fitxers CSV que tinguem dins de Google Drive.**
# Així, no haurem d'adjuntar el fitxer CSV cada cop que es vulgui executar el quadern.
# Es tracta doncs de posar una carpeta dins de Google Drive que serà accessible a Google Colab per poder portar les dades al quadern.

# %% [markdown]
# # 1.5 Exercici Quadern

# %% [markdown]
# Es pot observar un intent de crear un quadern amb estructura: índex amb seccions 1.1, 1.2, etc. (insert --> section header cell) . **Exercici: investiga les funcions més rellevants que podem trobar en el menú de l'esquerra, en el menú superior i dins la pestanya + Text.**

# %% [markdown]
# # 1.6 Exercici Personalització

# %% [markdown]
# **Què vol dir personalitzar?** En aquest quadern s'ha estructurat el contingut i s'ha posa't el logo de la EEBE i l'autor. Molt quaderns que trobem a Google no presenten aquest detalls. si el contingut es nostre, podem posar el nostre nom i si el contingut és d'un altre autor, cal citar-ho correctament. Cal tenir cura en no utilitzar diversos idiomes alhora, perquè es dificulta la comprensió. Caldria veure com millorar la part d'incorporació d'imatges, ja que és bastant millorable el que s'ha fet en aquest quadern.
